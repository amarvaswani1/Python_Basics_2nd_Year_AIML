# %%
list1=['a','b','c','d']
list2=['apple','ball','cat','dog']

list1.append('e')
print(list1)
# Out:
# ['a', 'b', 'c', 'd', 'e']

# %%
list1.append([1,2,3])
print(list1)

for i in list1:
    print(type(i))
# Out:
# ['a', 'b', 'c', 'd', 'e', [1, 2, 3]]
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'list'>

# %%
list1.append([55])
list1.append(True)
print(list1)

for i in list1:
    print(type(i))
# Out:
# ['a', 'b', 'c', 'd', 'e', [1, 2, 3], [55], True]
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'list'>
# <class 'list'>
# <class 'bool'>

# %%
list1.extend(['ABC','DCE'])
print(list1)
# Out:
# ['a', 'b', 'c', 'd', 'e', [1, 2, 3], [55], True, 'ABC', 'DCE']

# %%
list1.insert(1,'XYZ')
print(list1)
# Out:
# ['a', 'XYZ', 'b', 'c', 'd', 'e', [1, 2, 3], [55], True, 'ABC', 'DCE']

# %%
list1.insert(20,'PQR')
print(list1)
# Out:
# ['a', 'XYZ', 'b', 'c', 'd', 'e', [1, 2, 3], [55], True, 'ABC', 'DCE', 'PQR']

# %%
list1.pop()
print(list1)
# Out:
# ['a', 'XYZ', 'b', 'c', 'd', 'e', [1, 2, 3], [55], True, 'ABC', 'DCE']

# %%
list1.pop(1)
print(list1)
# Out:
# ['a', 'b', 'c', 'd', 'e', [1, 2, 3], [55], True, 'ABC', 'DCE']

# %%
list1.remove('ABC')
print(list1)
# Out:
# ['a', 'b', 'c', 'd', 'e', [1, 2, 3], [55], True, 'DCE']

# %%
list1.pop()
print(list1)
# Out:
# ['a', 'b', 'c', 'd', 'e', [1, 2, 3], [55], True]

# %%
list1.pop()
print(list1)
# Out:
# ['a', 'b', 'c', 'd', 'e', [1, 2, 3], [55]]

# %%
list1.pop()
print(list1)
# Out:
# ['a', 'b', 'c', 'd', 'e', [1, 2, 3]]

# %%
list1.pop()
print(list1)
# Out:
# ['a', 'b', 'c', 'd', 'e']

# %%
l1=['a','b','c','d']
print(l1[2])
# Out:
# c

# %%
#dictonary
d1={'Name':'Amar','Age':19,'Add':'Nagpur'}
print(d1)
# Out:
# {'Name': 'Amar', 'Age': 19, 'Add': 'Nagpur'}

# %%
print(d1['Age'])
# Out:
# 19

# %%
lista=[1,2,3,4]
listb=['a','b','c','d']
d2=dict(zip(lista,listb))
print(d2)
# Out:
# {1: 'a', 2: 'b', 3: 'c', 4: 'd'}

# %%
for x in d1.keys():
    print(x)
# Out:
# Name
# Age
# Add

# %%
for y in d1.values():
    print(y)
# Out:
# Amar
# 19
# Nagpur
